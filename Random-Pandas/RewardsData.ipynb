# %%
import pandas as pd

# %%
reward_df= pd.read_csv('RewardsData.csv')

# %%
reward_df.head()
# Out:
#    User ID  Birthdate           City     State    Zip  Available Points  \
# 0        1  1/31/1992   Minneapolis    Georgia  55401               300
# 1        2        NaN   Los Angeles   Colorado  90210               320
# 2        3  1/11/1990         Merida        AL  97204               330
# 3        4  4/16/1990  Winston-Salem        NC  27106             10790
# 4        5  3/24/1994  Winston-Salem        NC  27109               650
#
#    Total Points Earned  Points Spent         Joined On         Last Seen  \
# 0                  300             0     9/4/2020 0:15  12/16/2021 17:42
# 1                  320             0   8/19/2020 11:15   4/13/2022 14:28
# 2                  330             0  10/13/2020 16:20   4/21/2021 10:54
# 3                14290          3500   8/18/2020 13:21   6/30/2022 22:22
# 4                  650             0   8/21/2020 11:27  12/30/2020 10:57
#
#                                      Tags
# 0                             ClassOf2025
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile=ProfileReport(reward_df, title= 'Summary Report')

profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-02-24 21:19:13.393721&quot; name=date&gt;&lt;title&gt;Summary Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
reward_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7252 entries, 0 to 7251
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User ID              7252 non-null   int64
#  1   Birthdate            1172 non-null   object
#  2   City                 330 non-null    object
#  3   State                330 non-null    object
#  4   Zip                  330 non-null    object
#  5   Available Points     7252 non-null   int64
#  6   Total Points Earned  7252 non-null   int64
#  7   Points Spent         7252 non-null   int64
#  8   Joined On            7252 non-null   object
#  9   Last Seen            7031 non-null   object
#  10  Tags                 7252 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 623.3+ KB

# %%
reward_df.describe()
# Out:
#            User ID  Available Points  Total Points Earned  Points Spent
# count  7252.000000       7252.000000           7252.00000   7252.000000
# mean   3621.871484       1406.701737           1596.89203    191.383067
# std    2091.085954       2031.637229           2531.73693   1223.108659
# min       1.000000          0.000000            100.00000      0.000000
# 25%    1811.750000        400.000000            400.00000      0.000000
# 50%    3619.500000        735.000000            800.00000      0.000000
# 75%    5432.250000       1550.000000           1710.00000      0.000000
# max    7242.000000      52165.000000          59525.00000  57800.000000

# %%
reward_df.nunique()
# Out:
# User ID                7242
# Birthdate               958
# City                    149
# State                    42
# Zip                     170
# Available Points       1022
# Total Points Earned    1055
# Points Spent            139
# Joined On              5894
# Last Seen              6078
# Tags                    459
# dtype: int64

# %%
reward_df.shape
# Out:
# (7252, 11)

# %%
# select a single column

reward_df['City']
# Out:
# 0        Minneapolis
# 1        Los Angeles
# 2              Merida
# 3       Winston-Salem
# 4       Winston-Salem
#             ...
# 7247              NaN
# 7248              NaN
# 7249              NaN
# 7250              NaN
# 7251              NaN
# Name: City, Length: 7252, dtype: object

# %%
type(reward_df['City'])
# Out:
# pandas.core.series.Series

# %%
reward_df['City'].index.values
# Out:
# array([   0,    1,    2, ..., 7249, 7250, 7251], shape=(7252,))

# %%
reward_df.dtypes
# Out:
# User ID                 int64
# Birthdate              object
# City                   object
# State                  object
# Zip                    object
# Available Points        int64
# Total Points Earned     int64
# Points Spent            int64
# Joined On              object
# Last Seen              object
# Tags                   object
# dtype: object

# %%
reward_df['Available Points']=reward_df['Available Points'].astype(float)
reward_df.dtypes
# Out:
# User ID                  int64
# Birthdate               object
# City                    object
# State                   object
# Zip                     object
# Available Points       float64
# Total Points Earned      int64
# Points Spent             int64
# Joined On               object
# Last Seen               object
# Tags                    object
# dtype: object

# %%
locations_df= reward_df[['City','State', 'Zip']]
locations_df.head()
# Out:
#             City     State    Zip
# 0   Minneapolis    Georgia  55401
# 1   Los Angeles   Colorado  90210
# 2         Merida        AL  97204
# 3  Winston-Salem        NC  27106
# 4  Winston-Salem        NC  27109

# %%
reward_df.iloc[0]
# Out:
# User ID                               1
# Birthdate                     1/31/1992
# City                       Minneapolis
# State                           Georgia
# Zip                               55401
# Available Points                  300.0
# Total Points Earned                 300
# Points Spent                          0
# Joined On                 9/4/2020 0:15
# Last Seen              12/16/2021 17:42
# Tags                        ClassOf2025
# Name: 0, dtype: object

# %%
reward_df.iloc[1:4]
# Out:
#    User ID  Birthdate           City     State    Zip  Available Points  \
# 1        2        NaN   Los Angeles   Colorado  90210             320.0
# 2        3  1/11/1990         Merida        AL  97204             330.0
# 3        4  4/16/1990  Winston-Salem        NC  27106           10790.0
#
#    Total Points Earned  Points Spent         Joined On        Last Seen  \
# 1                  320             0   8/19/2020 11:15  4/13/2022 14:28
# 2                  330             0  10/13/2020 16:20  4/21/2021 10:54
# 3                14290          3500   8/18/2020 13:21  6/30/2022 22:22
#
#                               Tags
# 1                ClassOf2025|apple
# 2               Freshman|Developer
# 3  GraduateStudent|admin|MBBvsDuke

# %%
reward_df.set_index('State', inplace=True)
reward_df.head()
# Out:
#           User ID  Birthdate           City    Zip  Available Points  \
# State
# Georgia         1  1/31/1992   Minneapolis   55401             300.0
# Colorado        2        NaN   Los Angeles   90210             320.0
# AL              3  1/11/1990         Merida  97204             330.0
# NC              4  4/16/1990  Winston-Salem  27106           10790.0
# NC              5  3/24/1994  Winston-Salem  27109             650.0
#
#           Total Points Earned  Points Spent         Joined On  \
# State
# Georgia                   300             0     9/4/2020 0:15
# Colorado                  320             0   8/19/2020 11:15
# AL                        330             0  10/13/2020 16:20
# NC                      14290          3500   8/18/2020 13:21
# NC                        650             0   8/21/2020 11:27
#
#                  Last Seen                                    Tags
# State
# Georgia   12/16/2021 17:42                             ClassOf2025
# ...

# %%
georgia_df=reward_df.loc['Georgia']
georgia_df
georgia_df.shape
# Out:
# (3, 10)

# %%
top_earners_df=reward_df[reward_df['Total Points Earned']>25000]
top_earners_df.tail()
# Out:
#                 User ID  Birthdate           City    Zip  Available Points  \
# State
# NaN                1492  8/15/1998            NaN    NaN           12600.0
# North Carolina     1611        NaN  Winston-Salem  27109           23765.0
# Massachusetts      3055  6/10/2002         Bourne   2532           10890.0
# NaN                4654  12/3/1994            NaN    NaN            2045.0
# NaN                4681  1/20/1995            NaN    NaN           18190.0
#
#                 Total Points Earned  Points Spent        Joined On  \
# State
# NaN                           33300         20700  9/28/2020 22:16
# North Carolina                50165         26400  9/29/2020 21:53
# Massachusetts                 28890         18000  8/18/2021 10:05
# NaN                           26045         24000   9/2/2021 17:43
# NaN                           26690          8500   9/2/2021 18:54
#
#                       Last Seen                                   Tags
# State
# ...

# %%
top_earners_df.sort_values(by=['Total Points Earned'], ascending= False)
# Out:
#                 User ID  Birthdate           City    Zip  Available Points  \
# State
# NaN                 107   9/2/1998            NaN    NaN            1725.0
# Illinois           1243  5/14/2002       Waukegan  60085           52165.0
# North Carolina     1611        NaN  Winston-Salem  27109           23765.0
# NaN                1492  8/15/1998            NaN    NaN           12600.0
# Massachusetts      3055  6/10/2002         Bourne   2532           10890.0
# NaN                 644        NaN            NaN    NaN           21115.0
# NaN                4681  1/20/1995            NaN    NaN           18190.0
# NaN                4654  12/3/1994            NaN    NaN            2045.0
#
#                 Total Points Earned  Points Spent        Joined On  \
# State
# NaN                           59525         57800   9/7/2020 15:16
# Illinois                      52165             0   9/26/2020 1:22
# North Carolina                50165         26400  9/29/2020 21:53
# ...

# %%
top_earners_df.sort_values(by=['City','Total Points Earned'], ascending= False)
# Out:
#                 User ID  Birthdate           City    Zip  Available Points  \
# State
# North Carolina     1611        NaN  Winston-Salem  27109           23765.0
# Illinois           1243  5/14/2002       Waukegan  60085           52165.0
# Massachusetts      3055  6/10/2002         Bourne   2532           10890.0
# NaN                 107   9/2/1998            NaN    NaN            1725.0
# NaN                1492  8/15/1998            NaN    NaN           12600.0
# NaN                 644        NaN            NaN    NaN           21115.0
# NaN                4681  1/20/1995            NaN    NaN           18190.0
# NaN                4654  12/3/1994            NaN    NaN            2045.0
#
#                 Total Points Earned  Points Spent        Joined On  \
# State
# North Carolina                50165         26400  9/29/2020 21:53
# Illinois                      52165             0   9/26/2020 1:22
# Massachusetts                 28890         18000  8/18/2021 10:05
# ...

# %%
top_earners_df.sort_index()
# Out:
#                 User ID  Birthdate           City    Zip  Available Points  \
# State
# Illinois           1243  5/14/2002       Waukegan  60085           52165.0
# Massachusetts      3055  6/10/2002         Bourne   2532           10890.0
# North Carolina     1611        NaN  Winston-Salem  27109           23765.0
# NaN                 107   9/2/1998            NaN    NaN            1725.0
# NaN                 644        NaN            NaN    NaN           21115.0
# NaN                1492  8/15/1998            NaN    NaN           12600.0
# NaN                4654  12/3/1994            NaN    NaN            2045.0
# NaN                4681  1/20/1995            NaN    NaN           18190.0
#
#                 Total Points Earned  Points Spent        Joined On  \
# State
# Illinois                      52165             0   9/26/2020 1:22
# Massachusetts                 28890         18000  8/18/2021 10:05
# North Carolina                50165         26400  9/29/2020 21:53
# ...
